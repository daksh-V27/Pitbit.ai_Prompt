# %%
1+1
# Out:
# 2

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = OllamaEmbeddings()

# %%
text = "my name is daksh verma hello there i am 21 years old so i am going to be a bit tough this time and try to complete these embeddings quickly please"

# %%
query = embeddings.embed_query(text)
query[:]
# Out:
# [3.0712363719940186,
#  -2.0922114849090576,
#  -1.9665735960006714,
#  -0.9994322657585144,
#  -0.2609778344631195,
#  -0.9567765593528748,
#  -0.32089176774024963,
#  2.8850631713867188,
#  1.0252070426940918,
#  -0.2109215408563614,
#  1.367265224456787,
#  -0.3103708028793335,
#  -1.9195221662521362,
#  -3.0677571296691895,
#  -2.173171043395996,
#  1.8817274570465088,
#  0.03905482217669487,
#  2.1900112628936768,
#  0.16008254885673523,
#  -0.29822516441345215,
#  -0.48777469992637634,
#  -1.3189011812210083,
#  1.2553555965423584,
#  -0.5680801272392273,
#  -1.02418053150177,
#  1.965314507484436,
#  1.4068081378936768,
#  -2.044574499130249,
#  1.1463066339492798,
#  -0.48104724287986755,
#  -0.4780445992946625,
#  -0.07356555014848709,
#  -0.23899076879024506,
#  0.7717040181159973,
#  -1.2880529165267944,
#  1.1780444383621216,
#  -0.46409115195274353,
#  -1.133049488067627,
#  -1.6388109922409058,
#  -1.2263200283050537,
#  1.6351149082183838,
#  -0.4533367455005646,
# ...
